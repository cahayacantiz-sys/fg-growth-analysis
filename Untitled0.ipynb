# %% [markdown]
# <a href="https://colab.research.google.com/github/cahayacantiz-sys/fg-growth-analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mlxtend

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# Data transaksi
dataset = [
    ['Susu', 'Roti', 'Telur'],
    ['Roti', 'Mentega'],
    ['Susu', 'Telur'],
    ['Roti', 'Telur'],
    ['Susu', 'Roti', 'Mentega', 'Telur']
]

# Ubah data menjadi format tabel
te = TransactionEncoder()
te_data = te.fit(dataset).transform(dataset)

df = pd.DataFrame(te_data, columns=te.columns_)

print(df)
# Out:
#    Mentega   Roti   Susu  Telur
# 0    False   True   True   True
# 1     True   True  False  False
# 2    False  False   True   True
# 3    False   True  False   True
# 4     True   True   True   True

# %%
# FP-Growth
frequent_itemsets = fpgrowth(df, min_support=0.4, use_colnames=True)

print(frequent_itemsets)
# Out:
#    support             itemsets
# 0      0.8              (Telur)
# 1      0.8               (Roti)
# 2      0.6               (Susu)
# 3      0.4            (Mentega)
# 4      0.6        (Telur, Roti)
# 5      0.6        (Telur, Susu)
# 6      0.4         (Roti, Susu)
# 7      0.4  (Telur, Roti, Susu)
# 8      0.4      (Roti, Mentega)

# %%
# Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

print(rules)
# Out:
#     antecedents consequents  antecedent support  ...  jaccard  certainty  kulczynski
# 0       (Telur)      (Roti)                 0.8  ...     0.60     -0.250       0.750
# 1        (Roti)     (Telur)                 0.8  ...     0.60     -0.250       0.750
# 2       (Telur)      (Susu)                 0.8  ...     0.75      0.375       0.875
# 3        (Susu)     (Telur)                 0.6  ...     0.75      1.000       0.875
# 4  (Roti, Susu)     (Telur)                 0.4  ...     0.50      1.000       0.750
# 5     (Mentega)      (Roti)                 0.4  ...     0.50      1.000       0.750
#
# [6 rows x 14 columns]
